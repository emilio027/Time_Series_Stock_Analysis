# %%
# !pip install yfinance

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
df_500 = pd.read_csv('500.csv')
df_500
# Out:
#      Unnamed: 0 Ticker             Company             GICS Sector  \
# 0             0    AMD                 AMD  Information Technology
# 1             1     ED          Con Edison               Utilities
# 2             2    GLW             Corning  Information Technology
# 3             3    DHR             Danaher             Health Care
# 4             4    DRI  Darden Restaurants  Consumer Discretionary
# ..          ...    ...                 ...                     ...
# 500         500   MTCH         Match Group  Communication Services
# 501         501   EPAM        EPAM Systems  Information Technology
# 502         502    FDS             FactSet              Financials
# 503         503   SBNY      Signature Bank              Financials
# 504         504   SEDG           SolarEdge  Information Technology
#
#                 GICS Sub Industries
# 0                    Semiconductors
# 1                Electric Utilities
# 2             Electronic Components
# ...

# %%
 companies_list = list(df_500['Ticker'])

# %%
#all_companies = yf.download(companies_list, start='1956-01-01', end='2021-12-01')

# %%
#all_companies

# %%
#all_companies.to_csv('all_companies.csv')

# %%
#all_companies.columns

# %%
all_companies_close = pd.read_csv('all_companies_close.csv',)
all_companies_close
# Out:
#            Date           A        AAL         AAP        AAPL        ABBV  \
# 0        1/2/62         NaN        NaN         NaN         NaN         NaN
# 1        1/3/62         NaN        NaN         NaN         NaN         NaN
# 2        1/4/62         NaN        NaN         NaN         NaN         NaN
# 3        1/5/62         NaN        NaN         NaN         NaN         NaN
# 4        1/8/62         NaN        NaN         NaN         NaN         NaN
# ...         ...         ...        ...         ...         ...         ...
# 15099  11/24/21  152.970001  19.459999  233.369995  161.940002  118.660004
# 15100  11/26/21  152.070007  17.750000  226.729996  156.809998  116.510002
# 15101  11/29/21  153.419998  17.740000  227.270004  160.240005  116.889999
# 15102  11/30/21  150.899994  17.690001  220.720001  165.300003  115.279999
# 15103   12/1/21         NaN        NaN         NaN         NaN         NaN
#
# ...

# %%
all_companies_close.set_index('Date', inplace=True)
all_companies_close
# Out:
#                    A        AAL         AAP        AAPL        ABBV  \
# Date
# 1/2/62           NaN        NaN         NaN         NaN         NaN
# 1/3/62           NaN        NaN         NaN         NaN         NaN
# 1/4/62           NaN        NaN         NaN         NaN         NaN
# 1/5/62           NaN        NaN         NaN         NaN         NaN
# 1/8/62           NaN        NaN         NaN         NaN         NaN
# ...              ...        ...         ...         ...         ...
# 11/24/21  152.970001  19.459999  233.369995  161.940002  118.660004
# 11/26/21  152.070007  17.750000  226.729996  156.809998  116.510002
# 11/29/21  153.419998  17.740000  227.270004  160.240005  116.889999
# 11/30/21  150.899994  17.690001  220.720001  165.300003  115.279999
# 12/1/21          NaN        NaN         NaN         NaN         NaN
#
#                  ABC        ABMD         ABT         ACN        ADBE  ...  \
# ...

# %%
all_companies_close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15104 entries, 1/2/62 to 12/1/21
# Columns: 505 entries, A to ZTS
# dtypes: float64(505)
# memory usage: 58.3+ MB

# %%
all_companies_close.to_csv('close_date_index.csv')

# %% [markdown]
# # Sector DF

# %%
sector_df = pd.read_csv('500.csv')
sector_df
# Out:
#      Unnamed: 0 Ticker             Company             GICS Sector  \
# 0             0    AMD                 AMD  Information Technology
# 1             1     ED          Con Edison               Utilities
# 2             2    GLW             Corning  Information Technology
# 3             3    DHR             Danaher             Health Care
# 4             4    DRI  Darden Restaurants  Consumer Discretionary
# ..          ...    ...                 ...                     ...
# 500         500   MTCH         Match Group  Communication Services
# 501         501   EPAM        EPAM Systems  Information Technology
# 502         502    FDS             FactSet              Financials
# 503         503   SBNY      Signature Bank              Financials
# 504         504   SEDG           SolarEdge  Information Technology
#
#                 GICS Sub Industries
# 0                    Semiconductors
# 1                Electric Utilities
# 2             Electronic Components
# ...

# %%
sector_df.drop(columns=('Unnamed: 0'), inplace=True)
sector_df
# Out:
#     Ticker             Company             GICS Sector  \
# 0      AMD                 AMD  Information Technology
# 1       ED          Con Edison               Utilities
# 2      GLW             Corning  Information Technology
# 3      DHR             Danaher             Health Care
# 4      DRI  Darden Restaurants  Consumer Discretionary
# ..     ...                 ...                     ...
# 500   MTCH         Match Group  Communication Services
# 501   EPAM        EPAM Systems  Information Technology
# 502    FDS             FactSet              Financials
# 503   SBNY      Signature Bank              Financials
# 504   SEDG           SolarEdge  Information Technology
#
#                 GICS Sub Industries
# 0                    Semiconductors
# 1                Electric Utilities
# 2             Electronic Components
# 3             Health Care Equipment
# 4                       Restaurants
# ..                              ...
# 500    Interactive Media & Services
# ...

# %%
sector_df.drop(columns=('GICS Sub Industries'), inplace=True)
sector_df
# Out:
#     Ticker             Company             GICS Sector
# 0      AMD                 AMD  Information Technology
# 1       ED          Con Edison               Utilities
# 2      GLW             Corning  Information Technology
# 3      DHR             Danaher             Health Care
# 4      DRI  Darden Restaurants  Consumer Discretionary
# ..     ...                 ...                     ...
# 500   MTCH         Match Group  Communication Services
# 501   EPAM        EPAM Systems  Information Technology
# 502    FDS             FactSet              Financials
# 503   SBNY      Signature Bank              Financials
# 504   SEDG           SolarEdge  Information Technology
#
# [505 rows x 3 columns]

# %% [markdown]
# # SPY DF

# %%
spy_ohlc_df = yf.download('SPY', start='2017-03-06', end='2022-01-21')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy_ohlc_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-03-06  237.500000  238.119995  237.009995  237.710007  217.560532
# 2017-03-07  237.360001  237.770004  236.759995  237.000000  216.910660
# 2017-03-08  237.339996  237.639999  236.399994  236.559998  216.507996
# 2017-03-09  236.699997  237.240005  235.740005  236.860001  216.782578
# 2017-03-10  237.970001  238.020004  236.589996  237.690002  217.542221
# ...                ...         ...         ...         ...         ...
# 2022-01-13  472.190002  472.880005  463.440002  464.529999  464.529999
# 2022-01-14  461.190002  465.089996  459.899994  464.720001  464.720001
# 2022-01-18  459.739990  459.959991  455.309998  456.489990  456.489990
# 2022-01-19  458.130005  459.609985  451.459991  451.750000  451.750000
# 2022-01-20  453.750000  458.739990  444.500000  446.750000  446.750000
#
#                Volume
# Date
# 2017-03-06   55391500
# 2017-03-07   65103700
# 2017-03-08   78168800
# ...

# %%
sp500 = yf.Ticker('^GSPC')
sp500_hist = sp500.history(period='5y')
sp500_hist
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2017-01-30  2286.010010  2286.010010  2268.040039  2280.899902  3591270000
# 2017-01-31  2274.020020  2279.090088  2267.209961  2278.870117  4087450000
# 2017-02-01  2285.590088  2289.139893  2272.439941  2279.550049  3916610000
# 2017-02-02  2276.689941  2283.969971  2271.649902  2280.850098  3807710000
# 2017-02-03  2288.540039  2298.310059  2287.879883  2297.419922  3597970000
# ...                 ...          ...          ...          ...         ...
# 2022-01-21  4471.379883  4494.520020  4395.339844  4397.939941  3945810000
# 2022-01-24  4356.319824  4417.350098  4222.620117  4410.129883  5172540000
# 2022-01-25  4366.640137  4411.009766  4287.109863  4356.450195  3989420000
# 2022-01-26  4408.430176  4453.229980  4304.799805  4349.930176  4046270000
# 2022-01-28  4336.189941  4432.720215  4292.459961  4431.850098  3936030000
#
#             Dividends  Stock Splits
# Date
# ...

# %%
sp500_hist.drop(columns=(['Open','High','Low','Volume','Dividends','Stock Splits']), inplace=True)
sp500_hist
# Out:
#                   Close
# Date
# 2017-01-30  2280.899902
# 2017-01-31  2278.870117
# 2017-02-01  2279.550049
# 2017-02-02  2280.850098
# 2017-02-03  2297.419922
# ...                 ...
# 2022-01-21  4397.939941
# 2022-01-24  4410.129883
# 2022-01-25  4356.450195
# 2022-01-26  4349.930176
# 2022-01-28  4431.850098
#
# [1259 rows x 1 columns]

# %%
sp500_hist.reset_index(inplace=True)

# %%
sp500_hist.to_csv('spy.csv')

# %%
sp500 = yf.Ticker('^GSPC')
sp500_hist_2 = sp500.history(period='71y')
sp500_hist_2
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1951-01-29    21.670000    21.670000    21.670000    21.670000     2630000
# 1951-01-30    21.740000    21.740000    21.740000    21.740000     2480000
# 1951-01-31    21.660000    21.660000    21.660000    21.660000     2340000
# 1951-02-01    21.770000    21.770000    21.770000    21.770000     2380000
# 1951-02-02    21.959999    21.959999    21.959999    21.959999     3030000
# ...                 ...          ...          ...          ...         ...
# 2022-01-21  4471.379883  4494.520020  4395.339844  4397.939941  3945810000
# 2022-01-24  4356.319824  4417.350098  4222.620117  4410.129883  5172540000
# 2022-01-25  4366.640137  4411.009766  4287.109863  4356.450195  3989420000
# 2022-01-26  4408.430176  4453.229980  4304.799805  4349.930176  4046270000
# 2022-01-28  4336.189941  4432.720215  4292.459961  4431.850098  3936030000
#
#             Dividends  Stock Splits
# Date
# ...

# %%
sp500_hist_2.reset_index(inplace=True)
sp500_hist_2
# Out:
#             Date         Open         High          Low        Close  \
# 0     1951-01-29    21.670000    21.670000    21.670000    21.670000
# 1     1951-01-30    21.740000    21.740000    21.740000    21.740000
# 2     1951-01-31    21.660000    21.660000    21.660000    21.660000
# 3     1951-02-01    21.770000    21.770000    21.770000    21.770000
# 4     1951-02-02    21.959999    21.959999    21.959999    21.959999
# ...          ...          ...          ...          ...          ...
# 17863 2022-01-21  4471.379883  4494.520020  4395.339844  4397.939941
# 17864 2022-01-24  4356.319824  4417.350098  4222.620117  4410.129883
# 17865 2022-01-25  4366.640137  4411.009766  4287.109863  4356.450195
# 17866 2022-01-26  4408.430176  4453.229980  4304.799805  4349.930176
# 17867 2022-01-28  4336.189941  4432.720215  4292.459961  4431.850098
#
#            Volume  Dividends  Stock Splits
# 0         2630000          0             0
# 1         2480000          0             0
# ...

# %%
sp500_hist_2.drop(columns=(['Open','High','Low','Volume','Dividends','Stock Splits']), inplace=True)
sp500_hist_2
# Out:
#             Date        Close
# 0     1951-01-29    21.670000
# 1     1951-01-30    21.740000
# 2     1951-01-31    21.660000
# 3     1951-02-01    21.770000
# 4     1951-02-02    21.959999
# ...          ...          ...
# 17863 2022-01-21  4397.939941
# 17864 2022-01-24  4410.129883
# 17865 2022-01-25  4356.450195
# 17866 2022-01-26  4349.930176
# 17867 2022-01-28  4431.850098
#
# [17868 rows x 2 columns]

# %%
sp500_hist_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17868 entries, 0 to 17867
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    17868 non-null  datetime64[ns]
#  1   Close   17868 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 279.3 KB
