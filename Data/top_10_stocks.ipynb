# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
 companies_list = ['FRT','TTD','EPAM','APTV','SWK','MO','NEM','MELI','ADBE','AAPL']

# %%
top_companies = yf.download(companies_list, start='2017-03-06', end='2022-1-24')
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
top_companies
# Out:
#              Adj Close                                                  \
#                   AAPL        ADBE        APTV        EPAM         FRT
# Date
# 2017-03-06   32.931705  120.150002   61.930206   73.320000  112.287064
# 2017-03-07   32.974258  119.980003   61.970989   72.580002  111.526245
# 2017-03-08   32.851353  119.599998   62.509373   73.320000  109.109940
# 2017-03-09   32.775723  119.910004   62.232029   73.580002  106.551491
# 2017-03-10   32.884449  121.089996   62.884621   73.790001  106.989632
# ...                ...         ...         ...         ...         ...
# 2022-01-14  173.070007  520.599976  152.600006  543.059998  132.860001
# 2022-01-18  169.800003  513.340027  149.559998  505.950012  130.020004
# 2022-01-19  166.229996  516.580017  145.880005  493.980011  125.620003
# 2022-01-20  164.509995  510.850006  142.000000  486.070007  123.400002
# 2022-01-21  162.410004  499.910004  140.190002  464.709991  123.220001
#
# ...

# %%
top_companies.to_csv('top_10.csv')

# %%
top_companies_close = pd.read_csv('top_10_close.csv')
top_companies_close
# Out:
#            Date        AAPL        ADBE        APTV        EPAM         FRT  \
# 0    2017-03-06   34.834999  120.150001   63.637890   73.320000  134.300003
# 1    2017-03-07   34.880001  119.980003   63.679798   72.580002  133.389999
# 2    2017-03-08   34.750000  119.599999   64.233025   73.320000  130.500000
# 3    2017-03-09   34.669998  119.910004   63.948029   73.580002  127.440002
# 4    2017-03-10   34.785000  121.089996   64.618607   73.790001  126.980003
# ..          ...         ...         ...         ...         ...         ...
# 974  2021-01-15  127.139999  458.079987  142.750000  348.010010   87.269997
# 975  2021-01-19  127.830002  456.500000  142.570007  351.410004   87.199997
# 976  2021-01-20  132.029999  469.730011  145.119995  363.899994   88.250000
# 977  2021-01-21  136.869995  472.019989  143.850006  363.260010   86.959999
# 978  2021-01-22  139.070007  472.440002  139.490005  359.690002   88.529999
#
# ...

# %%
top_companies_close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    979 non-null    object
#  1   AAPL    979 non-null    float64
#  2   ADBE    979 non-null    float64
#  3   APTV    979 non-null    float64
#  4   EPAM    979 non-null    float64
#  5   FRT     979 non-null    float64
#  6   MELI    979 non-null    float64
#  7   MO      979 non-null    float64
#  8   NEM     979 non-null    float64
#  9   SWK     979 non-null    float64
#  10  TTD     979 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 84.3+ KB

# %%
top_companies
# Out:
#              Adj Close                                                  \
#                   AAPL        ADBE        APTV        EPAM         FRT
# Date
# 2017-03-06   32.931705  120.150002   61.930206   73.320000  112.287064
# 2017-03-07   32.974258  119.980003   61.970989   72.580002  111.526245
# 2017-03-08   32.851353  119.599998   62.509373   73.320000  109.109940
# 2017-03-09   32.775723  119.910004   62.232029   73.580002  106.551491
# 2017-03-10   32.884449  121.089996   62.884621   73.790001  106.989632
# ...                ...         ...         ...         ...         ...
# 2022-01-14  173.070007  520.599976  152.600006  543.059998  132.860001
# 2022-01-18  169.800003  513.340027  149.559998  505.950012  130.020004
# 2022-01-19  166.229996  516.580017  145.880005  493.980011  125.620003
# 2022-01-20  164.509995  510.850006  142.000000  486.070007  123.400002
# 2022-01-21  162.410004  499.910004  140.190002  464.709991  123.220001
#
# ...

# %%
top_companies.to_csv('top10.csv')

# %%
aapl_df = top_companies[['Date','AAPL']].copy()
aapl_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-254b5387f0d6> in <module>
# ----> 1 aapl_df = top_companies[['Date','AAPL']].copy()
#       2 aapl_df
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1238         # Have the index compute an indexer or return None
#    1239         # if it cannot handle:
# -> 1240         indexer, keyarr = ax._convert_listlike_indexer(key)
# ...

# %%
aapl_df.to_csv('aapl_2.csv')
