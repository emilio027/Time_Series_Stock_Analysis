# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("apple.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1231 entries, 0 to 1230
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1231 non-null   object
#  1   AAPL    1231 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.4+ KB

# %%
df.tail()
# Out:
#             Date        AAPL
# 1226  2022-01-14  173.070007
# 1227  2022-01-18  169.800003
# 1228  2022-01-19  166.229996
# 1229  2022-01-20  164.509995
# 1230  2022-01-21  162.410004

# %%
px.line(df, x = df.Date, y = df.AAPL)
# Out:
# <div>                            <div id="52c92d81-abac-402d-bb3f-d2da0eef66b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52c92d81-abac-402d-bb3f-d2da0eef66b9")) {                    Plotly.newPlot(                        "52c92d81-abac-402d-bb3f-d2da0eef66b9",                        [{"hovertemplate": "Date=%{x}<br>AAPL=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30",
# ...
