# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from cycler import cycler

rcParams['figure.figsize'] = 18, 5
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
rcParams['axes.prop_cycle'] = cycler(color=['#365977'])
rcParams['lines.linewidth'] = 2.5


# Load
df = pd.read_csv('MO.csv', index_col='Date', parse_dates=True)

# Visualize
plt.title('MO Price', size=20)
plt.plot(df);

# %%
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import confusion_matrix, plot_confusion_matrix,\
    precision_score, recall_score, accuracy_score, f1_score, log_loss,\
    roc_curve, roc_auc_score, classification_report
from sklearn.metrics import mean_squared_error

# %%
df
# Out:
#                MO
# Date
# 2017-03-06  75.58
# 2017-03-07  76.10
# 2017-03-08  75.84
# 2017-03-09  76.19
# 2017-03-10  76.45
# ...           ...
# 2022-01-14  50.81
# 2022-01-18  50.46
# 2022-01-19  50.09
# 2022-01-20  50.33
# 2022-01-21  50.32
#
# [1231 rows x 1 columns]

# %%
test_size = 253


df_train = df[:-test_size]
df_test = df[-test_size:]

plt.title('MO train and test sets', size=20)
plt.plot(df_train, label='Training set')
plt.plot(df_test, label='Test set', color='orange')
plt.legend();

# %%
from fbprophet import Prophet as proph

# %%
df_train
# Out:
#                MO
# Date
# 2017-03-06  75.58
# 2017-03-07  76.10
# 2017-03-08  75.84
# 2017-03-09  76.19
# 2017-03-10  76.45
# ...           ...
# 2021-01-14  41.11
# 2021-01-15  41.20
# 2021-01-19  41.23
# 2021-01-20  42.10
# 2021-01-21  41.94
#
# [978 rows x 1 columns]

# %%
df_train.reset_index(inplace=True)

# %%
df_test
# Out:
#                MO
# Date
# 2021-01-22  41.83
# 2021-01-25  41.96
# 2021-01-26  42.23
# 2021-01-27  41.82
# 2021-01-28  42.65
# ...           ...
# 2022-01-14  50.81
# 2022-01-18  50.46
# 2022-01-19  50.09
# 2022-01-20  50.33
# 2022-01-21  50.32
#
# [253 rows x 1 columns]

# %%
df_test.reset_index(inplace=True)

# %%
# Rename the columns [Date,AAPL] to [ds, y]

ts = df_train

ts = df_train.rename(columns={'Date': 'ds',
                        'MO': 'y'})

ts_test = df_test.rename(columns={'Date': 'ds',
                        'MO': 'y'})
ts.head(5)
# Out:
#           ds      y
# 0 2017-03-06  75.58
# 1 2017-03-07  76.10
# 2 2017-03-08  75.84
# 3 2017-03-09  76.19
# 4 2017-03-10  76.45

# %%
x_test = ts_test[['ds']]

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)

Model = proph(interval_width=0.95,daily_seasonality=True)

# %%
# Fit the timeseries into Model
Model.fit(ts)

# %%
# USe make_future_dataframe with a monthly frequency and periods = 759 for 3 years
future_dates = Model.make_future_dataframe(periods=759, freq='D')
future_dates.tail()
# Out:
#              ds
# 1732 2023-02-15
# 1733 2023-02-16
# 1734 2023-02-17
# 1735 2023-02-18
# 1736 2023-02-19

# %%
future_dates
# Out:
#              ds
# 0    2017-03-06
# 1    2017-03-07
# 2    2017-03-08
# 3    2017-03-09
# 4    2017-03-10
# ...         ...
# 1732 2023-02-15
# 1733 2023-02-16
# 1734 2023-02-17
# 1735 2023-02-18
# 1736 2023-02-19
#
# [1737 rows x 1 columns]

# %%
future_dates= future_dates.loc[future_dates['ds'] >= '2021-01-22']

# %%
x_test = pd.DataFrame(x_test)

# %%
x_test
# Out:
#             ds
# 0   2021-01-22
# 1   2021-01-25
# 2   2021-01-26
# 3   2021-01-27
# 4   2021-01-28
# ..         ...
# 248 2022-01-14
# 249 2022-01-18
# 250 2022-01-19
# 251 2022-01-20
# 252 2022-01-21
#
# [253 rows x 1 columns]

# %%
# Predict the values for future dates and take the head of forecast

predicitons = Model.predict(x_test)

# %%
forecast = Model.predict(future_dates)

# %%
forecast.tail()
# Out:
#             ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 754 2023-02-15  31.304489   19.318477   44.384706    20.916809    42.590213
# 755 2023-02-16  31.294784   19.224722   43.500978    20.895226    42.603725
# 756 2023-02-17  31.285078   18.876101   44.316265    20.873408    42.617231
# 757 2023-02-18  31.275372   19.232532   44.248186    20.851574    42.630729
# 758 2023-02-19  31.265666   18.598514   44.001283    20.829741    42.644228
#
#      additive_terms  additive_terms_lower  additive_terms_upper     daily  \
# 754        0.022089              0.022089              0.022089  0.401639
# 755       -0.104325             -0.104325             -0.104325  0.401639
# 756       -0.030115             -0.030115             -0.030115  0.401639
# 757       -0.021042             -0.021042             -0.021042  0.401639
# 758        0.040725              0.040725              0.040725  0.401639
#
#      ...    weekly  weekly_lower  weekly_upper    yearly  yearly_lower  \
# 754  ...  0.077342      0.077342      0.077342 -0.456892     -0.456892
# 755  ... -0.058603     -0.058603     -0.058603 -0.447360     -0.447360
# 756  ... -0.013064     -0.013064     -0.013064 -0.418690     -0.418690
# 757  ... -0.050205     -0.050205     -0.050205 -0.372476     -0.372476
# 758  ... -0.050205     -0.050205     -0.050205 -0.310709     -0.310709
#
#      yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 754     -0.456892                   0.0                         0.0
# 755     -0.447360                   0.0                         0.0
# 756     -0.418690                   0.0                         0.0
# 757     -0.372476                   0.0                         0.0
# 758     -0.310709                   0.0                         0.0
#
#      multiplicative_terms_upper       yhat
# 754                         0.0  31.326578
# 755                         0.0  31.190459
# 756                         0.0  31.254963
# 757                         0.0  31.254330
# 758                         0.0  31.306391
#
# [5 rows x 22 columns]

# %%
# Use prophet's plot function to plot the predictions

Model.plot(forecast, uncertainty=True)
plt.show()

# %%
Model.plot_components(forecast)
plt.show()

# %%
df_test = pd.concat([df_test,predicitons], axis=1)
df_test
# Out:
#           Date     MO         ds      trend  yhat_lower  yhat_upper  \
# 0   2021-01-22  41.83 2021-01-22  38.622602   34.708311   48.058086
# 1   2021-01-25  41.96 2021-01-25  38.593484   34.287328   47.213911
# 2   2021-01-26  42.23 2021-01-26  38.583779   34.697673   48.028732
# 3   2021-01-27  41.82 2021-01-27  38.574073   34.202276   47.672283
# 4   2021-01-28  42.65 2021-01-28  38.564367   33.982042   46.892712
# ..         ...    ...        ...        ...         ...         ...
# 248 2022-01-14  50.81 2022-01-14  35.157660   30.326392   44.711473
# 249 2022-01-18  50.46 2022-01-18  35.118837   30.143256   44.786563
# 250 2022-01-19  50.09 2022-01-19  35.109131   29.992789   45.297004
# 251 2022-01-20  50.33 2022-01-20  35.099426   30.116293   44.955126
# 252 2022-01-21  50.32 2022-01-21  35.089720   30.229278   45.971449
#
#      trend_lower  trend_upper  additive_terms  additive_terms_lower  ...  \
# 0      38.622602    38.622602        2.711739              2.711739  ...
# 1      38.592641    38.593493        2.539453              2.539453  ...
# 2      38.582108    38.585529        2.543025              2.543025  ...
# 3      38.571164    38.577450        2.405802              2.405802  ...
# 4      38.560103    38.570461        2.137423              2.137423  ...
# ..           ...          ...             ...                   ...  ...
# 248    31.596697    39.142804        2.473957              2.473957  ...
# 249    31.475271    39.184887        2.802764              2.802764  ...
# 250    31.444915    39.189710        2.811922              2.811922  ...
# 251    31.414558    39.194326        2.691831              2.691831  ...
# 252    31.384202    39.198823        2.737046              2.737046  ...
#
#        weekly  weekly_lower  weekly_upper    yearly  yearly_lower  \
# 0   -0.013064     -0.013064     -0.013064  2.323164      2.323164
# 1   -0.003656     -0.003656     -0.003656  2.141470      2.141470
# 2    0.098391      0.098391      0.098391  2.042996      2.042996
# 3    0.077342      0.077342      0.077342  1.926822      1.926822
# 4   -0.058603     -0.058603     -0.058603  1.794387      1.794387
# ..        ...           ...           ...       ...           ...
# 248 -0.013064     -0.013064     -0.013064  2.085381      2.085381
# 249  0.098391      0.098391      0.098391  2.302734      2.302734
# 250  0.077342      0.077342      0.077342  2.332942      2.332942
# 251 -0.058603     -0.058603     -0.058603  2.348795      2.348795
# 252 -0.013064     -0.013064     -0.013064  2.348471      2.348471
#
#      yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0        2.323164                   0.0                         0.0
# 1        2.141470                   0.0                         0.0
# 2        2.042996                   0.0                         0.0
# 3        1.926822                   0.0                         0.0
# 4        1.794387                   0.0                         0.0
# ..            ...                   ...                         ...
# 248      2.085381                   0.0                         0.0
# 249      2.302734                   0.0                         0.0
# 250      2.332942                   0.0                         0.0
# 251      2.348795                   0.0                         0.0
# 252      2.348471                   0.0                         0.0
#
#      multiplicative_terms_upper       yhat
# 0                           0.0  41.334340
# 1                           0.0  41.132937
# 2                           0.0  41.126804
# 3                           0.0  40.979875
# 4                           0.0  40.701790
# ..                          ...        ...
# 248                         0.0  37.631616
# 249                         0.0  37.921601
# 250                         0.0  37.921053
# 251                         0.0  37.791256
# 252                         0.0  37.826766
#
# [253 rows x 24 columns]

# %%
forecast
# Out:
#             ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2021-01-22  38.622602   35.102124   47.839840    38.622602    38.622602
# 1   2021-01-23  38.612896   34.437422   47.573644    38.612896    38.612896
# 2   2021-01-24  38.603190   34.397797   47.736906    38.602810    38.603190
# 3   2021-01-25  38.593484   34.918460   47.105202    38.592310    38.594018
# 4   2021-01-26  38.583779   34.481609   47.516548    38.581509    38.585111
# ..         ...        ...         ...         ...          ...          ...
# 754 2023-02-15  31.304489   19.318477   44.384706    20.916809    42.590213
# 755 2023-02-16  31.294784   19.224722   43.500978    20.895226    42.603725
# 756 2023-02-17  31.285078   18.876101   44.316265    20.873408    42.617231
# 757 2023-02-18  31.275372   19.232532   44.248186    20.851574    42.630729
# 758 2023-02-19  31.265666   18.598514   44.001283    20.829741    42.644228
#
#      additive_terms  additive_terms_lower  additive_terms_upper     daily  \
# 0          2.711739              2.711739              2.711739  0.401639
# 1          2.633267              2.633267              2.633267  0.401639
# 2          2.572690              2.572690              2.572690  0.401639
# 3          2.539453              2.539453              2.539453  0.401639
# 4          2.543025              2.543025              2.543025  0.401639
# ..              ...                   ...                   ...       ...
# 754        0.022089              0.022089              0.022089  0.401639
# 755       -0.104325             -0.104325             -0.104325  0.401639
# 756       -0.030115             -0.030115             -0.030115  0.401639
# 757       -0.021042             -0.021042             -0.021042  0.401639
# 758        0.040725              0.040725              0.040725  0.401639
#
#      ...    weekly  weekly_lower  weekly_upper    yearly  yearly_lower  \
# 0    ... -0.013064     -0.013064     -0.013064  2.323164      2.323164
# 1    ... -0.050205     -0.050205     -0.050205  2.281833      2.281833
# 2    ... -0.050205     -0.050205     -0.050205  2.221256      2.221256
# 3    ... -0.003656     -0.003656     -0.003656  2.141470      2.141470
# 4    ...  0.098391      0.098391      0.098391  2.042996      2.042996
# ..   ...       ...           ...           ...       ...           ...
# 754  ...  0.077342      0.077342      0.077342 -0.456892     -0.456892
# 755  ... -0.058603     -0.058603     -0.058603 -0.447360     -0.447360
# 756  ... -0.013064     -0.013064     -0.013064 -0.418690     -0.418690
# 757  ... -0.050205     -0.050205     -0.050205 -0.372476     -0.372476
# 758  ... -0.050205     -0.050205     -0.050205 -0.310709     -0.310709
#
#      yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0        2.323164                   0.0                         0.0
# 1        2.281833                   0.0                         0.0
# 2        2.221256                   0.0                         0.0
# 3        2.141470                   0.0                         0.0
# 4        2.042996                   0.0                         0.0
# ..            ...                   ...                         ...
# 754     -0.456892                   0.0                         0.0
# 755     -0.447360                   0.0                         0.0
# 756     -0.418690                   0.0                         0.0
# 757     -0.372476                   0.0                         0.0
# 758     -0.310709                   0.0                         0.0
#
#      multiplicative_terms_upper       yhat
# 0                           0.0  41.334340
# 1                           0.0  41.246163
# 2                           0.0  41.175880
# 3                           0.0  41.132937
# 4                           0.0  41.126804
# ..                          ...        ...
# 754                         0.0  31.326578
# 755                         0.0  31.190459
# 756                         0.0  31.254963
# 757                         0.0  31.254330
# 758                         0.0  31.306391
#
# [759 rows x 22 columns]

# %%
mean_squared_error(df_test.MO,df_test.yhat,squared=False)
# Out:
# 10.771266134670466
